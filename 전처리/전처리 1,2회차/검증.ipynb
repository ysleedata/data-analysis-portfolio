# %%
print("hello world")
# Out:
# hello world

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.iloc[4]
df.iloc[1, 8]
# Out:
# 'PC 17599'

# %%
df.loc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.loc[1:3, ['Survived', 'Name', 'Sex','Age']]
# Out:
#    Survived                                               Name     Sex   Age
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0

# %%
s = pd.Series(["윤서", "규리","영탁"], index=['a','b','c'], name='basic')

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.values
# Out:
# array(['윤서', '규리', '영탁'], dtype=object)

# %%
s1 = pd.Series([100, 200], index=['A','B'])
s2 = pd.Series([1, 2],     index=['B','C'])

print(s1 + s2)
# Out:
# A      NaN
# B    201.0
# C      NaN
# dtype: float64

# %%
df = pd.DataFrame({'name' : ['lee', 'seo'], 'age' : [20, 22]})

# %%
df.shape
# Out:
# (2, 2)

# %%
df.head()
# Out:
#   name  age
# 0  lee   20
# 1  seo   22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
df.to_csv('preprocessed_train.csv', index=False) # 인덱스는 저장하지 마라!

# %%
df = pd.DataFrame({ "name": ["천준석", "어제연", "이현지", "문길래"], "grade": ["F", "S", "SS", "SSS" ], "power": ["very weak", "strong", "strong", "very strong"]}, index=[10,20,30,40])
df
# Out:
#    name grade        power
# 10  천준석     F    very weak
# 20  어제연     S       strong
# 30  이현지    SS       strong
# 40  문길래   SSS  very strong

# %%
# 1 20, 30의 이름과 힘을 기입할 것임
# 2 어제연의 그레이드와 힘
# 3 천, 어, 이의 그래이드 출력
