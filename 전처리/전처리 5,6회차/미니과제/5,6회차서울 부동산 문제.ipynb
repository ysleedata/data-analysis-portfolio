# %% [markdown]
# # 서울시 부동산 2024 데이터 문제

# %%
import pandas as pd

# 서울시 부동산 데이터는 보통 cp949 인코딩이 많습니다.
df = pd.read_csv("2024.csv", encoding="cp949", low_memory=False)
print(df.shape)
df.head()

# %% [markdown]
# ---
#
# ### 문제 1 — 시간: `계약일` -> datetime 변환
# • `계약일`(예: 20241014)을 문자열로 바꾼 뒤 `format='%Y%m%d'`로 `pd.to_datetime` 하여 `계약일_dt` 컬럼을 만드세요. (`errors='coerce'`도 함께!)
# • 변환 후 `dtype` 확인까지!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 2 — 시간: 계약 연/월/일 파생컬럼 만들기
# • 1번에서 만든 `계약일_dt`로부터
#   - `계약연` (`.dt.year`)
#   - `계약월` (`.dt.month`)
#   - `계약일자` (`.dt.day`)
#   컬럼을 만들어보세요.

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 3 — 그룹화+agg: 자치구별 거래건수 & 평균 거래금액
# • `자치구명`별로
#   - 거래건수(count)
#   - 평균 거래금액(mean)
#   을 한 번에 구하고, 거래건수 기준 내림차순으로 정렬하세요.

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 4 — 복수 기준 그룹화: (자치구, 건물용도) 요약
# • `['자치구명', '건물용도']`로 그룹화해서
#   - 거래건수
#   - 평균 거래금액
#   - 중앙값 거래금액
#   을 한 번에 구하세요. (`agg`)
#   - count를 기준으로 내림차순 정렬 필수
# • 거래건수 TOP 10만 확인!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 5 — transform: 자치구 평균 금액 대비(차이) 컬럼 만들기
# • 자치구별 평균 거래금액을 각 행에 붙여 `구평균금액` 컬럼을 만들고
#   `금액_구평균차` = `물건금액(만원) - 구평균금액` 컬럼을 추가하세요. (`transform`)
# • 5행만 확인!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 6 — unstack: 자치구 × 건물용도 거래건수 표
# • (자치구명, 건물용도) 조합별 거래건수를 구한 뒤 `unstack()`으로 표를 만드세요.
# • 결측 조합은 0으로 채우기!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 7 — 단가 계산: ㎡당 단가(만원/㎡) + 자치구별 평균 단가
# • `단가_만원_㎡ = 물건금액(만원) / 건물면적(㎡)` 컬럼을 만드세요. (벡터 연산 추천)
# • 그리고 자치구별 평균 단가 TOP 10을 확인해보세요.
# • 값 내림차순 정렬은 필수겠죠?

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 8 — pivot_table: 계약월 × 건물용도 평균 단가 표
# • `pivot_table`로 아래 표를 만드세요.
#   - index: `계약월`
#   - columns: `건물용도`
#   - values: `단가_만원_㎡`
#   - aggfunc: mean
#   - 빈 값은 0으로

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 9 — melt: 8번 피벗 표를 long으로
# • 8번 `unit_pivot`을 long 형태로 바꾸세요.
# • 결과 컬럼: `계약월`, `건물용도`, `avg_unit_price`

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 10 — pivot: 9번 long을 다시 wide로 복원
# • 9번 `unit_long`을 `pivot`으로 다시 wide로 바꾸고
#   8번 `unit_pivot`과 같은지 확인해보세요. (`equals`)

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 11 — 문자열 정리: `건물명` 클린 컬럼 만들기(괄호 제거 포함)
# • `건물명_clean`을 만들어봅시다. 규칙:
#   - 결측은 `'미상'`
#   - 괄호 '(' ')' 제거
#   - 양끝 공백 제거
# • 클린 전/후 5개만 비교 출력!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 12 — 문자열 contains: 빌라 거래 건수 + 자치구 TOP 5
# • `건물명_clean`에 빌라가 포함된 거래만 필터링해서 전체 건수를 구하세요.
# • 그리고 자치구별 빌라 거래건수 TOP 5도 확인해봅시다.
# • 내림차순 값 정렬!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 13 — 문자열: 법정동명 마지막 글자 빈도 TOP 10
# • `법정동명`의 마지막 글자를 `동_끝글자` 컬럼으로 만들고
#   빈도 상위 10개를 출력하세요. (힌트: `.str[-1]`)

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 14 — map: 신고구분 설명 라벨 붙이기
# • 예시 매핑을 참고해서 `신고구분_설명` 컬럼을 만드세요.
# •   - '중개거래' -> '중개사 통해 거래'
#   - '직거래' -> '직접 거래'
# • 설명 라벨별 거래건수를 출력하세요.
#
# • 매핑에 없는 값은 NaN이 되므로 `fillna('기타')`

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 15 — 시간: `취소일` datetime 변환 + 계약일과의 차이(일수)
# • `취소일`을 datetime으로 변환해 `취소일_dt` 컬럼을 만드세요. (`format='%Y%m%d'`, `errors='coerce'`)
# • 그리고 `days_to_cancel = 취소일_dt - 계약일_dt`의 일수 차이를 계산하세요.
# • `days_to_cancel`의 결측치 개수도 확인!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 16 — merge: 자치구 -> 권역 매핑 붙이기 + 권역별 평균금액
# • 아래 5개 권역 기준으로 `자치구명-권역` 매핑 DataFrame을 만들어 `left merge` 하세요.
#   - 도심권: 종로구, 중구, 용산구
#   - 동북권: 성동구, 광진구, 동대문구, 중랑구, 성북구, 강북구, 도봉구, 노원구
#   - 서북권: 은평구, 서대문구, 마포구
#   - 서남권: 양천구, 강서구, 구로구, 금천구, 영등포구, 동작구, 관악구
#   - 동남권: 서초구, 강남구, 송파구, 강동구
# • 병합 후 `권역`별 평균 거래금액을 비교해보세요.

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 17 — set_index: 계약일을 인덱스로 두고 특정 월 데이터 슬라이싱
# • `계약일_dt`를 인덱스로 설정하고 정렬한 뒤,
#   **2024년 10월 거래만** 슬라이싱해서 건수를 확인해보세요.
#   - 힌트: DatetimeIndex면 `df_idx.loc['2024-10']` 같은 방식이 됩니다.
# • 마지막에 `reset_index()`로 원복!

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.

# %% [markdown]
# ---
#
# ### 문제 18 — concat: 신고구분별 월별 평균금액 요약표 합치기
# • `중개거래`와 `직거래`를 각각 분리해서 각각 `계약월`별 평균 거래금액을 구한 뒤, 두 결과를 `concat`으로 위아래로 붙여 하나의 DataFrame으로 만드세요.
# • 최종 결과에는 `신고구분` 컬럼이 있어야 합니다.
# • 합친 데이터프레임의 인덱스 정리도 해야겠죠~?
# • `"계약월"`, `"신고구분"` 오름차순 정렬

# %%
# TODO: 여기에서 풀이 코드를 작성하세요.
