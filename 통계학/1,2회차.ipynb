# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\python_course\.venv\lib\site-packages (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\python_course\.venv\lib\site-packages (from scipy) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd # 표 형태 데이터를 다루는 가장 중요한 라이브러리
import numpy as np # 수학 계산, 행렬 연산, 난수 생성
import matplotlib.pyplot as plt # 기본 그래프 라이브러리, 선 그래프, 막대 그래프, 히스토그램 등
import seaborn as sns # matplotlib을 더 예쁘게. 히트맵, 분포 그래프, 박스플롯
import scipy.stats as stats # 통계 분석용 함수 모음, t-test, 정규성 검정, 상관계수 등 가설검정 시 사용
import math # 제곱근, 로그, 삼각함수 같은 단순 계산
import platform #지금 실행 중인 운영체제 정보 확인
import os # 경로 이동, 파일 존재 확인, 폴더 생성 등.
import glob # 특정 패턴의 파일 여러 개 한 번에 찾기

pd.set_option('display.float_format',"{:.2f}".format) 
# set_option -> pandas의 전체 출력 설정을 바꾼다.
# 보이는 형식만 소수점 둘째자리까지 보이도록 함

# OS에 따라 다른 폰트 지정
if platform.system() == 'Darwin':   # macOS
    plt.rcParams['font.family'] = 'AppleGothic'
elif platform.system() == 'Windows':  # Windows
    plt.rcParams['font.family'] = 'Malgun Gothic'
else:  # Linux (예: Colab, Ubuntu)
    plt.rcParams['font.family'] = 'NanumGothic'

file_path = "../통계학/2024.csv"
df = pd.read_csv(file_path,encoding='cp949', parse_dates=["계약일","취소일"])
# parse_dates=["계약일","취소일"] -> 두 컬럼을 문자열이 아니라 날짜(datetime) 타입으로 자동 변환
# 데이터를 “불러올 때” 전처리를 최대한 끝내라
# Out:
# C:\Users\j2h09\AppData\Local\Temp\ipykernel_8912\2248707656.py:22: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path,encoding='cp949', parse_dates=["계약일","취소일"])

# %% [markdown]
# 데이터의 유형

# %%
df.shape
# Out:
# (77523, 21)

# %%
df.head().T # 행과 열을 전치하여 보여줌.
# Out:
#                                     0                    1  \
# 접수연도                             2024                 2024
# 자치구코드                           11380                11500
# 자치구명                              은평구                  강서구
# 법정동코드                           10200                10300
# 법정동명                              녹번동                  화곡동
# 지번구분                             1.00                 1.00
# 지번구분명                              대지                   대지
# 본번                              86.00               924.00
# 부번                             125.00                 4.00
# 건물명                      성원빌라(86-125)                 팔팔빌라
# 계약일               2024-10-14 00:00:00  2024-10-14 00:00:00
# 물건금액(만원)                        16400                35000
# 건물면적(㎡)                         53.07                39.24
# 토지면적(㎡)                         25.00                27.00
# 층                                4.00                 2.00
# 권리구분                              NaN                  NaN
# 취소일                               NaT                  NaT
# 건축년도                          1991.00              1986.00
# 건물용도                            연립다세대                연립다세대
# 신고구분                             중개거래                  직거래
# 신고한 개업공인중개사 시군구명               서울 은평구                  NaN
#
#                                     2                    3  \
# 접수연도                             2024                 2024
# 자치구코드                           11560                11560
# 자치구명                             영등포구                 영등포구
# 법정동코드                           11100                12800
# 법정동명                            당산동1가                양평동4가
# 지번구분                             1.00                 1.00
# 지번구분명                              대지                   대지
# 본번                             143.00               220.00
# 부번                               0.00                 0.00
# 건물명                            다솔시티하임                  해울빌
# 계약일               2024-10-14 00:00:00  2024-10-14 00:00:00
# 물건금액(만원)                        30000                36000
# 건물면적(㎡)                         29.54                40.41
# 토지면적(㎡)                         14.00                63.64
# 층                                5.00                 3.00
# 권리구분                              NaN                  NaN
# 취소일                               NaT                  NaT
# 건축년도                          2017.00              2021.00
# 건물용도                            연립다세대                 오피스텔
# 신고구분                              직거래                 중개거래
# 신고한 개업공인중개사 시군구명                  NaN               서울 용산구
#
#                                     4
# 접수연도                             2024
# 자치구코드                           11410
# 자치구명                             서대문구
# 법정동코드                           11200
# 법정동명                              대현동
# 지번구분                             1.00
# 지번구분명                              대지
# 본번                              90.00
# 부번                              77.00
# 건물명                            유씨유 이대
# 계약일               2024-10-14 00:00:00
# 물건금액(만원)                        19300
# 건물면적(㎡)                         17.31
# 토지면적(㎡)                         30.87
# 층                                5.00
# 권리구분                              NaN
# 취소일                               NaT
# 건축년도                          2018.00
# 건물용도                             오피스텔
# 신고구분                             중개거래
# 신고한 개업공인중개사 시군구명              서울 서대문구

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77523 entries, 0 to 77522
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   접수연도              77523 non-null  int64
#  1   자치구코드             77523 non-null  int64
#  2   자치구명              77522 non-null  object
#  3   법정동코드             77523 non-null  int64
#  4   법정동명              77523 non-null  object
#  5   지번구분              74965 non-null  float64
#  6   지번구분명             74965 non-null  object
#  7   본번                74964 non-null  object
#  8   부번                74964 non-null  object
#  9   건물명               74964 non-null  object
#  10  계약일               77523 non-null  datetime64[ns]
#  11  물건금액(만원)          77523 non-null  int64
#  12  건물면적(㎡)           77523 non-null  float64
#  13  토지면적(㎡)           72446 non-null  float64
#  14  층                 74965 non-null  float64
#  15  권리구분              700 non-null    object
#  16  취소일               3172 non-null   datetime64[ns]
#  17  건축년도              77256 non-null  float64
#  18  건물용도              77523 non-null  object
#  19  신고구분              77521 non-null  object
#  20  신고한 개업공인중개사 시군구명  68669 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(4), object(10)
# memory usage: 12.4+ MB

# %% [markdown]
# ## 실습 1. 숫자형 컬럼을 데이터 유형별로 나누기
#
# ---
#
# ### 실습 조건
# - **연도(year)에 해당하는 컬럼은 본 실습에서 제외한다**
# - 연도 컬럼은 분석 목적에 따라 양적·질적으로 다르게 해석될 수 있으므로,
#   본 실습에서는 데이터 유형 분류 대상에서 제외한다
#
# ---
#
# ### 1. 양적 데이터 (Quantitative Data)
#
# 숫자로 측정할 수 있으며, **크기·차이·연산**이 의미 있는 데이터
#
# | 구분 | 설명 | 예시 |
# |---|---|---|
# | 연속형 (Continuous) | 측정 가능한 실수 값 | 키, 몸무게, 온도, 시간 |
# | 이산형 (Discrete) | 측정 가능한 정수 값 | 구매 횟수, 방문자 수, 자녀 수 |
#
# ---
#
# ### 2. 질적 데이터 (Qualitative Data)
#
# 대상을 **특성·범주·종류**로 구분하는 데이터
# (숫자로 표현될 수 있으나, 산술 연산은 의미 없음)
#
# | 구분 | 설명 | 예시 |
# |---|---|---|
# | 명목형 (Nominal) | 순서가 없는 범주 | 성별, 혈액형, 국가 |
# | 순서형 (Ordinal) | 순서는 있으나 간격의 크기는 의미 없음 | 만족도, 선호도 순위, 등급 |

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.drop(columns=['접수연도', '건축년도'], inplace=True)
# 첫줄 뜻: DataFrame에서 숫자 타입 컬럼만 골라서 새로운 DataFrame 생성
#

# %%
numeric_df.columns = ['자치구코드', '법정동코드', '지번구분', '물건금액', '건물면적', '토지면적', '층']
numeric_df
# Out:
#        자치구코드  법정동코드  지번구분    물건금액   건물면적   토지면적    층
# 0      11380  10200  1.00   16400  53.07  25.00 4.00
# 1      11500  10300  1.00   35000  39.24  27.00 2.00
# 2      11560  11100  1.00   30000  29.54  14.00 5.00
# 3      11560  12800  1.00   36000  40.41  63.64 3.00
# 4      11410  11200  1.00   19300  17.31  30.87 5.00
# ...      ...    ...   ...     ...    ...    ...  ...
# 77518  11530  10700  1.00    9190  53.61 124.00 1.00
# 77519  11530  10700  1.00    9190  53.61 124.00 1.00
# 77520  11530  10700  1.00    9740  53.61 124.00 2.00
# 77521  11440  11000   NaN  195000 157.45 116.70  NaN
# 77522  11305  10100   NaN  164000 293.08 136.00  NaN
#
# [77523 rows x 7 columns]

# %% [markdown]
# 명목형, 순서형, 연속형, 이산형 중 어디에 해당되는지 써보기
#
# - 자치구코드 명목형
# - 법정동코드 명목형
# - 지번구분 명목형
# - 물건금액 이산형 (땡...) 대표적인 연속형, 1.64만원의 경우를 생각하면 됨
# - 건물면적 연속형
# - 토지면적 연속형
# - 층 순서형 (떙...) 층은 이산형/명목형

# %%
df.describe() #구간 확인 가능
# Out:
#           접수연도    자치구코드    법정동코드     지번구분                            계약일  \
# count 77523.00 77523.00 77523.00 74965.00                          77523
# mean   2024.00 11456.36 10948.61     1.00  2024-05-24 23:35:51.139661824
# min    2024.00 11110.00 10100.00     1.00            2021-02-08 00:00:00
# 25%    2024.00 11305.00 10200.00     1.00            2024-03-27 00:00:00
# 50%    2024.00 11470.00 10600.00     1.00            2024-06-05 00:00:00
# 75%    2024.00 11620.00 11000.00     1.00            2024-07-24 00:00:00
# max    2024.00 26230.00 18700.00     3.00            2024-10-14 00:00:00
# std       0.00   186.07  1228.36     0.09                            NaN
#
#         물건금액(만원)  건물면적(㎡)  토지면적(㎡)        층                            취소일  \
# count   77523.00 77523.00 72446.00 74965.00                           3172
# mean    88598.66    68.03    18.65     7.89  2024-06-15 19:38:30.718789120
# min      2600.00     8.48     0.00    -2.00            2024-01-02 00:00:00
# 25%     32000.00    41.85     0.00     3.00            2024-04-23 00:00:00
# 50%     66000.00    59.92     0.00     6.00            2024-06-24 00:00:00
# 75%    115000.00    84.87    27.00    11.00            2024-08-17 00:00:00
# max   2850000.00  2932.27 30822.00    68.00            2024-10-14 00:00:00
# std     87195.98    53.12   122.38     6.32                            NaN
#
#           건축년도
# count 77256.00
# mean   1986.78
# min       0.00
# 25%    1996.00
# 50%    2004.00
# 75%    2016.00
# max    2024.00
# std     190.38

# %%
continuous_cols = ["물건금액", "토지면적", "건물면적"]
conti_df = numeric_df[continuous_cols].copy()

# %%
conti_df.describe()
# Out:
#             물건금액     토지면적     건물면적
# count   77523.00 72446.00 77523.00
# mean    88598.66    18.65    68.03
# std     87195.98   122.38    53.12
# min      2600.00     0.00     8.48
# 25%     32000.00     0.00    41.85
# 50%     66000.00     0.00    59.92
# 75%    115000.00    27.00    84.87
# max   2850000.00 30822.00  2932.27

# %%
conti_df.hist()
plt.show()

# %%
plt.hist(conti_df['건물면적'],bins=10, edgecolor='black')
plt.show()

# %% [markdown]
# 실습 3. IQR 방식의 이상치 제거

# %%
area_data = conti_df['토지면적'].dropna().values
q_1 = np.percentile(area_data, q=25)
q_3 = np.percentile(area_data, q=75)
iqr = q_3 - q_1
q_1, q_3, iqr
# Out:
# (np.float64(0.0), np.float64(27.0), np.float64(27.0))

# %%
#하한
lower_whisker = q_1 - iqr*1.5
#상한 
upper_whisker = q_3 + iqr*1.5
conti_df.loc[(conti_df['토지면적']<lower_whisker)|(conti_df['토지면적']>upper_whisker)]
# Out:
#          물건금액   토지면적    건물면적
# 5      744000 534.00 1502.31
# 12      69000  90.00  136.16
# 64      30000 157.00  194.85
# 148    185000 154.00  230.41
# 154     30800  91.00   61.87
# ...       ...    ...     ...
# 77518    9190 124.00   53.61
# 77519    9190 124.00   53.61
# 77520    9740 124.00   53.61
# 77521  195000 116.70  157.45
# 77522  164000 136.00  293.08
#
# [3680 rows x 3 columns]

# %%
plt.boxplot(area_data)
plt.show()

# %%
outliers = conti_df.loc[(conti_df['토지면적']<lower_whisker)|(conti_df['토지면적']>upper_whisker)]

area_data_cleaned = conti_df.loc[(conti_df['토지면적']>=lower_whisker)&(conti_df['토지면적']<=upper_whisker), '토지면적']
plt.hist(area_data_cleaned, bins=20)
plt.show()

# %%
plt.boxplot(area_data_cleaned)
plt.show()

# %% [markdown]
# ## 추론통계

# %%
# 샘플 만들기
sample_df = conti_df.sample(200, random_state=42)

# %% [markdown]
# ### 실습4 샘플데이터와 전체 데이터 비교

# %%
sample_df.describe()
# Out:
#            물건금액   토지면적   건물면적
# count    200.00 188.00 200.00
# mean   88368.32  21.16  70.83
# std    76123.73  36.15  56.22
# min     8000.00   0.00  13.58
# 25%    33150.00   0.00  46.04
# 50%    67650.00   0.00  59.93
# 75%   118000.00  30.25  84.90
# max   507000.00 245.00 664.84

# %%
conti_df.describe()
# Out:
#             물건금액     토지면적     건물면적
# count   77523.00 72446.00 77523.00
# mean    88598.66    18.65    68.03
# std     87195.98   122.38    53.12
# min      2600.00     0.00     8.48
# 25%     32000.00     0.00    41.85
# 50%     66000.00     0.00    59.92
# 75%    115000.00    27.00    84.87
# max   2850000.00 30822.00  2932.27

# %% [markdown]
# ### 실습5 신뢰구간 구하기

# %%
sample_data = sample_df['토지면적']

# 표본 개수
n = len(sample_data)

# 표본 평균
sample_mean = np.mean(sample_data)

# 표본 표준편차
s = np.std(sample_data, ddof=1)

# 표준 오차 근사값
se = s/np.sqrt(n)

# 신뢰구간 구하기
stats.t.interval(confidence=0.95, df = n-1, loc = sample_mean , scale=se)
# Out:
# (np.float64(16.115903217249766), np.float64(26.198136144452363))
